# %% [markdown]
# <a href="https://colab.research.google.com/github/rijalammar1/PVCK_RijalAmmar/blob/main/Jobsheet12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import PIL
import io
import html
import time
# %matplotlib inline
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode

# %%
cascade = cv.CascadeClassifier('/content/drive/MyDrive/PVCK_MM/Images/haarcascade_frontalface_alt.xml')

#Jokowi
bpkjokowi = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/jokowi.jpg')
bpkjokowi1 = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/jokowi.jpg')
roi_wajah1 = cascade.detectMultiScale(bpkjokowi1) 

roi_wajah = cascade.detectMultiScale(bpkjokowi) 
for(x,y,w,h) in roi_wajah: 
 cv.rectangle(bpkjokowi,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(bpkjokowi1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(bpkjokowi1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(bpkjokowi, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(bpkjokowi, cv.COLOR_BGR2RGB))
plt.show()

# %%
# RA.Kartini
ibukartini = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/kartini.jpg')
ibukartini1 = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/kartini.jpg')
wajah1 = cascade.detectMultiScale(ibukartini1) 

wajah = cascade.detectMultiScale(ibukartini) 
for(x,y,w,h) in wajah: 
 cv.rectangle(ibukartini,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(ibukartini1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(ibukartini1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(ibukartini, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(ibukartini, cv.COLOR_BGR2RGB))
plt.show()

# %%
#Kucing
kucing = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/kucing.jpg')
kucing1 = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/kucing.jpg')

ori = cv.cvtColor(kucing, cv.COLOR_BGR2GRAY)
ori1 = cv.cvtColor(kucing1, cv.COLOR_BGR2GRAY)

wajah = cascade.detectMultiScale(kucing1)
for (x,y,w,h) in wajah: 
  cv.rectangle(kucing1,(x,y),(x+w,y+h),(255,0,255),3) 
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(ori, cmap='gray')
plt.subplot(122),plt.imshow(ori1, cmap='gray')
plt.show()

# %%
#Perempuan
mask = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/mask.png',0)
mask1 = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/mask.png',0)

wajah = cascade.detectMultiScale(mask1)
for(x,y,w,h) in wajah:
 cv.rectangle(mask1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))


f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(mask, cmap='gray')
plt.subplot(122),plt.imshow(mask1, cmap='gray')
plt.show()

# %%
#M.Jordan GOAT
mrjordan = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/mjordan.jpg',0)
mrjordan1 = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/mjordan.jpg',0)

wajah = cascade.detectMultiScale(mrjordan1)
for(x,y,w,h) in wajah:
 cv.rectangle(mrjordan1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(mrjordan, cmap='gray')
plt.subplot(122),plt.imshow(mrjordan1, cmap='gray')
plt.show()

# %%
#Group
Group = cv.imread('/content/drive/MyDrive/PVCK_MM/solvayconf.jpg')
Group1 = cv.imread('/content/drive/MyDrive/PVCK_MM/solvayconf.jpg')

wajah = cascade.detectMultiScale(Group1)
for(x,y,w,h) in wajah:
 cv.rectangle(Group1,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(Group, cmap='gray')
plt.subplot(122),plt.imshow(Group1, cmap='gray')
plt.show()

# %%
#Kucing
cat = cv.CascadeClassifier('/content/drive/MyDrive/PVCK_MM/Images/haarcascade_frontalface_alt.xml')

kucing = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/mycat.jpg', 0)
kucing1 = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/mycat.jpg', 0)

wajah = cat.detectMultiScale(kucing1, scaleFactor=1.3, minNeighbors=3, minSize=(50, 50))
for (x,y,w,h) in wajah: 
  cv.rectangle(kucing1,(x,y),(x+w,y+h),(225,0,225),3)
  break  

plt.figure(figsize = (10,10))
f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kucing, cmap='gray')
plt.subplot(122),plt.imshow(kucing1, cmap='gray')
plt.show()

# %%
# JOKOWI
wajah = cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_eye.xml")

bpkjokowi = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/jokowi.jpg')
bpkjokowi_ori = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/jokowi.jpg')
bpkjokowi_gray = cv.cvtColor(bpkjokowi, cv.COLOR_BGR2GRAY)
bpkjokowi_ori_gray = cv.cvtColor(bpkjokowi_ori, cv.COLOR_BGR2GRAY)

roi_wajah = wajah.detectMultiScale(bpkjokowi_gray)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(bpkjokowi_gray,(x,y),(x+w,y+h),(255,255,255),3)

# Plot outputs
f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121),plt.imshow(bpkjokowi_ori_gray, cmap='gray')
plt.subplot(122),plt.imshow(bpkjokowi_gray, cmap='gray')
plt.show()

# %%
# Kamera
import PIL
import io
import html
import time
# %matplotlib inline
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode


def js_to_image(js_reply):
  image_bytes = b64decode(js_reply.split(',')[1])
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  img = cv.imdecode(jpg_as_np, flags=1)

  return img


def bbox_to_bytes(bbox_array):
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  bbox_PIL.save(iobuf, format='png')
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64decode(iobuf.getvalue()), 'utf-8')))
  
  return bbox_to_bytes

face_cascade = cv.CascadeClassifier(cv.samples.findFile('/content/drive/MyDrive/PVCK_MM/Images/haarcascade_frontalface_default.xml'))

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality){
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  data = eval_js('takePhoto({})'.format(quality))
  img = js_to_image(data)
  gray = cv.cvtColor(img, cv.COLOR_RGB2GRAY)
  print(gray.shape)
  faces = face_cascade.detectMultiScale(gray)
  for(x,y,w,h) in faces:
    img = cv.rectangle(img,(x,y),(x+w,y+h),(255, 0, 0),2)

  cv.imwrite(filename, img)

  return filename

try:
  filename = take_photo('photo.jpg')
  print('Saved to {}'.format(filename))

  display(Image(filename))
except Exception as err:
  print(str(err))
# Out:
# (480, 640)
# Saved to photo.jpg

# %%
# Gambar Tempel

cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PVCK_MM/Images/haarcascade_frontalface_alt.xml')


img = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/mjordan.jpg')
smile = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/smile.png', cv.IMREAD_UNCHANGED)


gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)


faces = cascade_wajah.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

for (x, y, w, h) in faces:
    smile_resized = cv.resize(smile, (w, h))
    img[y:y+h, x:x+w] = cv.addWeighted(img[y:y+h, x:x+w], 1, smile_resized[:, :, 0:3], 1, 0)

# Display the images
plt.figure(figsize=(12, 6))
plt.subplot(122), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.show()

# %%
bounding_box = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/people.jpg')

bb_gray = cv.cvtColor(bounding_box, cv.COLOR_BGR2GRAY)

cascade = cv.CascadeClassifier('/content/drive/MyDrive/PVCK_MM/Images/haarcascade_frontalface_alt.xml')
roi_bb = cascade.detectMultiScale(bb_gray, scaleFactor=1.1, minNeighbors=5)

for (x, y, w, h) in roi_bb:
    cv.rectangle(bounding_box, (x, y), (x+w, y+h), (0, 0, 0), 2)

    roi_gray = bb_gray[y:y+h, x:x+w]
    eye_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PVCK_MM/Images/haarcascade_eye.xml')
    eyes = eye_cascade.detectMultiScale(roi_gray, scaleFactor=1.1, minNeighbors=5)

    for (ex, ey, ew, eh) in eyes:
        cv.rectangle(bounding_box, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 0, 255), 2)

        if ex + ew/2 > w/2:
            cv.rectangle(bounding_box, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (255, 255, 255), 2)

plt.figure(figsize=(15, 5))
plt.subplot(111), plt.imshow(cv.cvtColor(bounding_box, cv.COLOR_BGR2RGB))
plt.show()
