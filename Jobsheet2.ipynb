# %% [markdown]
# <a href="https://colab.research.google.com/github/rijalammar1/PVCK_RijalAmmar/blob/main/Jobsheet2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/kitten01.jpg')
plt.imshow(img)     #perhatikan hasilnya adalah citra dengan channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) # konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/Images/mandrill2.tiff', img5)

#tampilan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
# pembuatan black image dengan tipe data int32.
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tpe data int32
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
# Array tersebut kemudian di reshape sebagai berikut
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
# Penambahan polyline pada black image kedua yang telah dibuat.
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Pertanyaan
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# Jawaban
# 1. Perbedaannya yaitu jika menggunakan matplotlib maka kita akan mengetahui koordinat pixel dari gambar yang ditampilkan.
# 2. Perbedaannya adalah pada rentang nilai yang dapat ditampung, untuk int32 rentang nilai yang dapat ditampung lebih besar dari tipe data int16.
# 3. Kegunaannya adalah untuk mengimport class cv2_imshow pada package google
# sedangkan colab.patches. class cv2_imshow berfungsi untuk menampilkan gambar.
# 4. Kegunaannya adalah untuk membaca dan menulis gambar dalam berbagai format

# %%
# Tugas 8
# Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
img12 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img12,pt1=(0,700),pt2=(100,550),color=(0,255,255),thickness=10)
plt.imshow(img12)

# %%
# Tugas 6
# Tampilkan image dengan posisi terbalik! 
imgFlip = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
plt.imshow(imgFlip)

# %%
# Tugas 2
# Tampilkan image dalam channel Red-Blue 

img_rb = img.copy()

# Untuk Mesplit channels
b, g, r = cv.split(img)

# megabungkan chanel red dan blue
img_rb = cv.merge([r, b, b])

# menampilkan gambar
plt.imshow(img_rb)
plt.show()

# %%
# Tugas 2
# Tampilkan image dalam channel Green-Blue

img_rb = img.copy()

# Untuk Mesplit channels
b, g, r = cv.split(img)

# megabungkan chanel green dan blue
img_rb = cv.merge([g, b, b])

# menampilkan gambar
plt.imshow(img_rb)
plt.show()

# %%
#3. Menampilkan image baris ke 20-115, kolom 25-120

imgt = img[20:115,25:120]
plt.imshow(imgt)

# %%
#4. Menampilkan image baris ke 5-30, semua kolom, channel Red saja

img_rb = img.copy()

# memisahkan saluran warna merah
b, g, r = cv.split(img)
red_channel = r

# membuat citra hanya dengan saluran warna merah
img_red = cv.merge([red_channel, red_channel, red_channel])

# menampilkan citra hanya dengan saluran warna merah
plt.imshow(img_red[5:30], cmap='gray')
plt.show()

# %%
#5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.

img_rb = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(img_rb, pt1=(354,0), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_rb, pt1=(200,250), pt2=(510,150), color=(0,255,0), thickness=10)
cv.rectangle(img_rb, pt1=(500,500), pt2=(400,100), color=(255,255,255), thickness=10)
cv.rectangle(img_rb, pt1=(200,450), pt2=(600,550), color=(255,0,0), thickness=10)
cv.rectangle(img_rb, pt1=(200,100), pt2=(400,600), color=(0,0,255), thickness=10)

plt.imshow(img_rb)

# %%
# Tugas 9
# Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
font  = cv.FONT_HERSHEY_TRIPLEX
img12 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img12,pt1=(0,700),pt2=(100,550),color=(0,255,255),thickness=10)
cv.putText(img12, text="Hi Rijal!", org=(250,200), fontFace=font, fontScale=2, color =(255,0,0),thickness = 5, lineType = cv.LINE_AA)
plt.imshow(img12)

# %%
#7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto)

image1 = cv.imread('/content/drive/MyDrive/PVCK_MM/Images/IMG-20181112-WA0020.jpg')
image2 = cv.cvtColor(image1, cv.COLOR_BGR2RGB)

cv.rectangle(image2, pt1=(990,500), pt2 = (870,340), color= (225,0,255), thickness=30)
cv.circle(image2, center=(945,440),radius=55, color= (255,0,0), thickness=10)

plt.imshow(image2)
